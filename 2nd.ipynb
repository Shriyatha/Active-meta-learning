# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import matplotlib.pyplot as plt
import datetime
import random
import numpy as np
import os
import pickle
from google.colab import drive

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

CNPRegressionDescription = collections.namedtuple(
    "CNPRegressionDescription", ("query", "target_y")
)
class FunctionFamily:
    SINE = "sine"
    EXP = "exp"
    POLYNOMIAL = "polynomial"
    STRAIGHT_LINE = "straight_line"

class CurvesReader:
    """Generates curves from various function families with mixed sampling."""

    def __init__(self, batch_size, max_num_context, testing=False):
        self._batch_size = batch_size
        self._max_num_context = max_num_context
        self._testing = testing
        self._function_families = [
            FunctionFamily.SINE,
            FunctionFamily.EXP,
            FunctionFamily.POLYNOMIAL,
            FunctionFamily.STRAIGHT_LINE,
        ]

    def generate_curves(self, function_family=None):
        """Builds the op delivering the data with mixed function families."""

        # Sample number of context points
        num_context = torch.randint(low=3, high=self._max_num_context + 1, size=(1,))

        if self._testing:
            num_target = 400
            num_total_points = num_target
            x_values = torch.linspace(start=-2, end=2, steps=num_target).unsqueeze(0).repeat(self._batch_size, 1).unsqueeze(-1)
        else:
            num_target = torch.randint(low=3, high=self._max_num_context + 1, size=(1,))
            num_total_points = num_context + num_target
            x_values = (torch.rand((self._batch_size, num_total_points, 1))) * 4 - 2  # unif[-2, 2]

        # Randomly select function family if not specified
        if function_family is None:
            function_family = random.choice(self._function_families)

        # Generate different function types with random parameters
        if function_family == FunctionFamily.SINE:
            # Random amplitude (0.5-1.5), frequency (0.5-2.5), phase (0-2pi)
            amplitude = torch.rand(1) + 0.5
            frequency = torch.rand(1) * 2 + 0.5
            phase = torch.rand(1) * 2 * np.pi
            y_values = amplitude * torch.sin(frequency * x_values + phase)

        elif function_family == FunctionFamily.EXP:
            # Random scale (-0.5 to 0.5) and shift (-1 to 1)
            scale = torch.rand(1) - 0.5
            shift = torch.rand(1) * 2 - 1
            y_values = torch.exp(scale * x_values) + shift

        elif function_family == FunctionFamily.POLYNOMIAL:
            # Random quadratic coefficients (-1 to 1)
            coeffs = torch.rand(3) * 2 - 1
            y_values = coeffs[0] + coeffs[1] * x_values + coeffs[2] * x_values**2

        elif function_family == FunctionFamily.STRAIGHT_LINE:
            # Random slope (-1 to 1) and intercept (-2 to 2)
            slope = torch.rand(1) * 2 - 1
            intercept = torch.rand(1) * 4 - 2
            y_values = slope * x_values + intercept
        else:
            raise ValueError(f"Unknown function family: {function_family}")

        # Split into context and target points
        if self._testing:
            target_x = x_values
            target_y = y_values
            idx = torch.randperm(num_target)
            context_x = x_values[:, idx[:num_context], :]
            context_y = y_values[:, idx[:num_context], :]
        else:
            target_x = x_values[:, : num_target + num_context, :]
            target_y = y_values[:, : num_target + num_context, :]
            context_x = x_values[:, :num_context, :]
            context_y = y_values[:, :num_context, :]

        query = ((context_x, context_y), target_x)
        return CNPRegressionDescription(query=query, target_y=target_y), function_family

# Set random seeds for reproducibility
torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# Mount Google Drive (for saving datasets persistently)
drive.mount('/content/drive')


# Function families
class FunctionFamily:
    SINE = "sine"
    EXP = "exp"
    POLYNOMIAL = "polynomial"
    STRAIGHT_LINE = "straight_line"

function_families = [
    FunctionFamily.SINE,
    FunctionFamily.EXP,
    FunctionFamily.POLYNOMIAL,
    FunctionFamily.STRAIGHT_LINE,
]

# Dataset configuration
DATASET_NAME = "fixed_cnp_dataset.pkl"  # Single file for all datasets
DATASET_PATH = f"/content/drive/MyDrive/{DATASET_NAME}"

# =============================================
# Dataset Management
# =============================================
def generate_fixed_datasets():
    """Generate new fixed datasets for all function families"""
    print("Generating new fixed datasets...")

    test_readers = {
        family: CurvesReader(TEST_BATCH_SIZE, MAX_CONTEXT_POINTS, testing=True)
        for family in function_families
    }

    fixed_datasets = {}
    for family in function_families:
        fixed_datasets[family] = [
            test_readers[family].generate_curves(family)[0]
            for _ in range(NUM_TEST_TASKS)
        ]
        print(f"Generated {len(fixed_datasets[family])} tasks for {family}")

    return fixed_datasets

def save_datasets(datasets):
    """Save datasets to Google Drive"""
    with open(DATASET_PATH, 'wb') as f:
        pickle.dump({
            'creation_date': datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'parameters': {
                'test_batch_size': TEST_BATCH_SIZE,
                'max_context_points': MAX_CONTEXT_POINTS,
                'num_test_tasks': NUM_TEST_TASKS
            },
            'data': datasets
        }, f)
    print(f"Saved fixed datasets to {DATASET_PATH}")

def load_datasets():
    """Load datasets from Google Drive"""
    if not os.path.exists(DATASET_PATH):
        return None

    with open(DATASET_PATH, 'rb') as f:
        data = pickle.load(f)
        print(f"Loaded fixed datasets created on {data['creation_date']}")
        return data['data']

# Load or create fixed datasets
fixed_test_datasets = load_datasets()

if fixed_test_datasets is None:
    fixed_test_datasets = generate_fixed_datasets()
    save_datasets(fixed_test_datasets)
else:
    print("Using existing fixed datasets")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-07e3a66ff8d5> in <cell line: 0>()
#     106
#     107 # Mount Google Drive (for saving datasets persistently)
# --> 108 drive.mount('/content/drive')
#     109
#     110
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# Dataset configuration
DATASET_NAME = "fixed_cnp_dataset.pkl"  # Single file for all datasets
DATASET_PATH = f"/content/{DATASET_NAME}"
# =============================================
def generate_fixed_datasets():
    """Generate new fixed datasets for all function families"""
    print("Generating new fixed datasets...")

    test_readers = {
        family: CurvesReader(TEST_BATCH_SIZE, MAX_CONTEXT_POINTS, testing=True)
        for family in function_families
    }

    fixed_datasets = {}
    for family in function_families:
        fixed_datasets[family] = [
            test_readers[family].generate_curves(family)[0]
            for _ in range(NUM_TEST_TASKS)
        ]
        print(f"Generated {len(fixed_datasets[family])} tasks for {family}")

    return fixed_datasets

def save_datasets(datasets):
    """Save datasets to Google Drive"""
    with open(DATASET_PATH, 'wb') as f:
        pickle.dump({
            'creation_date': datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'parameters': {
                'test_batch_size': TEST_BATCH_SIZE,
                'max_context_points': MAX_CONTEXT_POINTS,
                'num_test_tasks': NUM_TEST_TASKS
            },
            'data': datasets
        }, f)
    print(f"Saved fixed datasets to {DATASET_PATH}")

def load_datasets():
    """Load datasets from Google Drive"""
    if not os.path.exists(DATASET_PATH):
        return None

    with open(DATASET_PATH, 'rb') as f:
        data = pickle.load(f)
        print(f"Loaded fixed datasets created on {data['creation_date']}")
        return data['data']

# Load or create fixed datasets
fixed_test_datasets = load_datasets()

if fixed_test_datasets is None:
    fixed_test_datasets = generate_fixed_datasets()
    save_datasets(fixed_test_datasets)
else:
    print("Using existing fixed datasets")
# Out:
# Loaded fixed datasets created on 2025-04-13 19:09:56
# Using existing fixed datasets

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import matplotlib.pyplot as plt
import datetime
import random
import numpy as np

class FunctionFamily:
    SINE = "sine"
    EXP = "exp"
    POLYNOMIAL = "polynomial"
    STRAIGHT_LINE = "straight_line"

function_families = [
    FunctionFamily.SINE,
    FunctionFamily.EXP,
    FunctionFamily.POLYNOMIAL,
    FunctionFamily.STRAIGHT_LINE,
]

class DeterministicEncoder(nn.Module):
    def __init__(self, sizes):
        super(DeterministicEncoder, self).__init__()
        self.linears = nn.ModuleList()
        for i in range(len(sizes) - 1):
            self.linears.append(nn.Linear(sizes[i], sizes[i + 1]))

    def forward(self, context_x, context_y):
        encoder_input = torch.cat((context_x, context_y), dim=-1)
        batch_size, set_size, filter_size = encoder_input.shape
        x = encoder_input.view(batch_size * set_size, -1)
        for i, linear in enumerate(self.linears[:-1]):
            x = torch.relu(linear(x))
        x = self.linears[-1](x)
        x = x.view(batch_size, set_size, -1)
        representation = x.mean(dim=1)
        return representation

class DeterministicDecoder(nn.Module):
    def __init__(self, sizes):
        super(DeterministicDecoder, self).__init__()
        self.linears = nn.ModuleList()
        for i in range(len(sizes) - 1):
            self.linears.append(nn.Linear(sizes[i], sizes[i + 1]))

    def forward(self, representation, target_x):
        batch_size, set_size, d = target_x.shape
        representation = representation.unsqueeze(1).repeat([1, set_size, 1])
        input = torch.cat((representation, target_x), dim=-1)
        x = input.view(batch_size * set_size, -1)
        for i, linear in enumerate(self.linears[:-1]):
            x = torch.relu(linear(x))
        x = self.linears[-1](x)
        out = x.view(batch_size, set_size, -1)
        mu, log_sigma = torch.split(out, 1, dim=-1)
        sigma = 0.1 + 0.9 * torch.nn.functional.softplus(log_sigma)
        dist = torch.distributions.normal.Normal(loc=mu, scale=sigma)
        return dist, mu, sigma

class DeterministicModel(nn.Module):
    def __init__(self, encoder_sizes, decoder_sizes):
        super(DeterministicModel, self).__init__()
        self._encoder = DeterministicEncoder(encoder_sizes)
        self._decoder = DeterministicDecoder(decoder_sizes)

    def forward(self, query, target_y=None):
        (context_x, context_y), target_x = query
        representation = self._encoder(context_x, context_y)
        dist, mu, sigma = self._decoder(representation, target_x)
        log_p = None if target_y is None else dist.log_prob(target_y)
        return log_p, mu, sigma

def plot_functions(target_x, target_y, context_x, context_y, pred_y, var, title=""):
    """Plots the predicted mean and variance and the context points."""
    plt.figure(figsize=(10, 6))
    plt.plot(target_x[0].squeeze(), pred_y[0].squeeze(), "b", linewidth=2, label='Prediction')
    plt.plot(target_x[0].squeeze(), target_y[0].squeeze(), "k:", linewidth=2, label='Truth')
    plt.plot(context_x[0].squeeze(), context_y[0].squeeze(), "ko", markersize=10, label='Context')
    plt.fill_between(
        target_x[0].squeeze(),
        (pred_y[0] - var[0]).squeeze(),
        (pred_y[0] + var[0]).squeeze(),
        alpha=0.2,
        facecolor="#65c9f7",
        interpolate=True,
        label='±1 std'
    )
    plt.legend()
    plt.ylim([-3, 3])
    plt.title(title)
    plt.show()

# Hyperparameters
TRAINING_ITERATIONS = int(1e5)
BLOCK_SIZE = 100
EVAL_AFTER = 500
MAX_CONTEXT_POINTS = 10
BATCH_SIZE = 64
TEST_BATCH_SIZE = 100
NUM_TEST_TASKS = 100
# Model and Optimizer
d_x, d_in, representation_size, d_out = 1, 2, 128, 2
encoder_sizes = [d_in, 128, 128, 128, representation_size]
decoder_sizes = [representation_size + d_x, 128, 128, 2]
model = DeterministicModel(encoder_sizes, decoder_sizes)
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Training statistics
mse_values = []
training_blocks = []
family_mses = {family: [] for family in function_families}
current_family = None

def evaluate_model(model, test_datasets, family_name=None):
    """Evaluates the model on test datasets and returns average MSE."""
    model.eval()
    total_mse = 0.0
    with torch.no_grad():
        for data_test in test_datasets:
            _, pred_y, _ = model(data_test.query, data_test.target_y)
            mse = torch.mean((pred_y - data_test.target_y)**2)
            total_mse += mse.item()
    model.train()
    avg_mse = total_mse / len(test_datasets)

    if family_name is not None:
        print(f"  {family_name}: MSE = {avg_mse:.4f}")

    return avg_mse

# Training loop with blocks
print(f"Starting training at {datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Training for {TRAINING_ITERATIONS} iterations with {BLOCK_SIZE}-iteration blocks")

train_reader = CurvesReader(BATCH_SIZE, MAX_CONTEXT_POINTS, testing=False)

for it in range(TRAINING_ITERATIONS):
    # Switch family at the start of each block
    if it % BLOCK_SIZE == 0:
        current_family = random.choice(function_families)
        print(f"\nBlock {it // BLOCK_SIZE + 1}: Training on {current_family}")

    # Generate training batch from current family
    data_train, _ = train_reader.generate_curves(current_family)

    # Train step
    optimizer.zero_grad()
    log_prob, _, _ = model(data_train.query, data_train.target_y)
    loss = -log_prob.mean()
    loss.backward()
    optimizer.step()

    # Evaluation (every EVAL_AFTER iterations)
    if (it + 1) % EVAL_AFTER == 0:
        print(f"\nEvaluation at iteration {it + 1}:")
        current_mses = {}
        total_mse = 0.0

        # Evaluate on all function families
        for family in function_families:
            family_mse = evaluate_model(model, fixed_test_datasets[family], family)
            current_mses[family] = family_mse
            family_mses[family].append(family_mse)
            total_mse += family_mse

        # Record overall performance
        avg_mse = total_mse / len(function_families)
        mse_values.append(avg_mse)
        training_blocks.append(it + 1)

        print(f"Average MSE across all families: {avg_mse:.4f}")

plt.figure(figsize=(12, 6))
line_styles = ['-', '--', '-.', ':']  # Different line styles for clarity

for i, family in enumerate(function_families):
    plt.plot(training_blocks, family_mses[family],
             label=family.capitalize(),
             linestyle=line_styles[i % len(line_styles)],
             linewidth=2)

# Add vertical lines for block boundaries
for block_start in range(0, TRAINING_ITERATIONS, BLOCK_SIZE):
    if block_start < training_blocks[-1]:
        plt.axvline(block_start, color='gray', linestyle=':', alpha=0.4)

plt.xlabel('Training Iterations', fontsize=12)
plt.ylabel('MSE', fontsize=12)
plt.title('CNP Performance by Function Family', fontsize=14)
plt.legend(fontsize=10, frameon=True)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Plot overall training curve
plt.figure(figsize=(12, 6))
plt.plot(training_blocks, mse_values,
         color='blue', linewidth=2,
         label='Average MSE')

# Mark the best performance
best_mse = min(mse_values)
best_idx = mse_values.index(best_mse)
plt.scatter(training_blocks[best_idx], best_mse,
            color='red', s=100,
            label=f'Best MSE: {best_mse:.4f}')

plt.xlabel('Training Iterations', fontsize=12)
plt.ylabel('Average MSE', fontsize=12)
plt.title('Overall Training Performance', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Final prediction plots
print("\nFinal Evaluation and Visualization:")
test_reader = CurvesReader(1, MAX_CONTEXT_POINTS, testing=True)
for family in function_families:
    data_test, _ = test_reader.generate_curves(family)
    with torch.no_grad():
        _, pred_y, var = model(data_test.query, data_test.target_y)
        (context_x, context_y), target_x = data_test.query
        plot_functions(
            target_x.detach().numpy(),
            data_test.target_y.detach().numpy(),
            context_x.detach().numpy(),
            context_y.detach().numpy(),
            pred_y.detach().numpy(),
            var.detach().numpy(),
            title=f"{family.capitalize()} Function Prediction"
        )
# Out:
# Starting training at 2025-04-14 12:37:47
# Training for 100000 iterations with 100-iteration blocks
#
# Block 1: Training on straight_line
#
# Block 2: Training on straight_line
#
# Block 3: Training on sine
#
# Block 4: Training on polynomial
#
# Block 5: Training on straight_line
#
# Evaluation at iteration 500:
#   sine: MSE = 0.6216
#   exp: MSE = 0.1543
#   polynomial: MSE = 1.0791
#   straight_line: MSE = 0.4237
# Average MSE across all families: 0.5697
#
# Block 6: Training on straight_line
#
# Block 7: Training on polynomial
#
# Block 8: Training on straight_line
#
# Block 9: Training on polynomial
#
# Block 10: Training on exp
#
# Evaluation at iteration 1000:
#   sine: MSE = 0.6250
#   exp: MSE = 0.1540
#   polynomial: MSE = 1.0961
#   straight_line: MSE = 0.4494
# Average MSE across all families: 0.5811
#
# Block 11: Training on exp
#
# Block 12: Training on polynomial
#
# Block 13: Training on exp
#
# Block 14: Training on sine
#
# Block 15: Training on polynomial
#
# Evaluation at iteration 1500:
#   sine: MSE = 0.5777
#   exp: MSE = 0.1484
#   polynomial: MSE = 1.0534
#   straight_line: MSE = 0.4205
# Average MSE across all families: 0.5500
#
# Block 16: Training on exp
#
# Block 17: Training on polynomial
#
# Block 18: Training on sine
#
# Block 19: Training on sine
#
# Block 20: Training on polynomial
#
# Evaluation at iteration 2000:
#   sine: MSE = 0.5597
#   exp: MSE = 0.1439
#   polynomial: MSE = 1.0333
#   straight_line: MSE = 0.3996
# Average MSE across all families: 0.5341
#
# Block 21: Training on straight_line
#
# Block 22: Training on sine
#
# Block 23: Training on polynomial
#
# Block 24: Training on straight_line
#
# Block 25: Training on polynomial
#
# Evaluation at iteration 2500:
#   sine: MSE = 0.5077
#   exp: MSE = 0.1098
#   polynomial: MSE = 0.9184
#   straight_line: MSE = 0.3008
# Average MSE across all families: 0.4591
#
# Block 26: Training on exp
#
# Block 27: Training on straight_line
#
# Block 28: Training on straight_line
#
# Block 29: Training on polynomial
#
# Block 30: Training on sine
#
# Evaluation at iteration 3000:
#   sine: MSE = 0.4235
#   exp: MSE = 0.1392
#   polynomial: MSE = 0.8565
#   straight_line: MSE = 0.2470
# Average MSE across all families: 0.4166
#
# Block 31: Training on sine
#
# Block 32: Training on sine
#
# Block 33: Training on straight_line
#
# Block 34: Training on sine
#
# Block 35: Training on straight_line
#
# Evaluation at iteration 3500:
#   sine: MSE = 0.4598
#   exp: MSE = 0.1195
#   polynomial: MSE = 0.8192
#   straight_line: MSE = 0.1653
# Average MSE across all families: 0.3909
#
# Block 36: Training on polynomial
#
# Block 37: Training on exp
#
# Block 38: Training on polynomial
#
# Block 39: Training on sine
#
# Block 40: Training on exp
#
# Evaluation at iteration 4000:
#   sine: MSE = 0.4764
#   exp: MSE = 0.0499
#   polynomial: MSE = 0.8035
#   straight_line: MSE = 0.1800
# Average MSE across all families: 0.3774
#
# Block 41: Training on exp
#
# Block 42: Training on exp
#
# Block 43: Training on exp
#
# Block 44: Training on straight_line
#
# Block 45: Training on sine
#
# Evaluation at iteration 4500:
#   sine: MSE = 0.4180
#   exp: MSE = 0.1213
#   polynomial: MSE = 0.8255
#   straight_line: MSE = 0.2075
# Average MSE across all families: 0.3931
#
# Block 46: Training on sine
#
# Block 47: Training on polynomial
#
# Block 48: Training on straight_line
#
# Block 49: Training on sine
#
# Block 50: Training on polynomial
#
# Evaluation at iteration 5000:
#   sine: MSE = 0.4227
#   exp: MSE = 0.0904
#   polynomial: MSE = 0.7771
#   straight_line: MSE = 0.1275
# Average MSE across all families: 0.3544
#
# Block 51: Training on polynomial
#
# Block 52: Training on sine
#
# Block 53: Training on polynomial
#
# Block 54: Training on exp
#
# Block 55: Training on polynomial
#
# Evaluation at iteration 5500:
#   sine: MSE = 0.4437
#   exp: MSE = 0.0945
#   polynomial: MSE = 0.7633
#   straight_line: MSE = 0.1314
# Average MSE across all families: 0.3582
#
# Block 56: Training on straight_line
#
# Block 57: Training on sine
#
# Block 58: Training on straight_line
#
# Block 59: Training on polynomial
#
# Block 60: Training on exp
#
# Evaluation at iteration 6000:
#   sine: MSE = 0.4666
#   exp: MSE = 0.0600
#   polynomial: MSE = 0.7592
#   straight_line: MSE = 0.1245
# Average MSE across all families: 0.3526
#
# Block 61: Training on polynomial
#
# Block 62: Training on exp
#
# Block 63: Training on exp
#
# Block 64: Training on exp
#
# Block 65: Training on sine
#
# Evaluation at iteration 6500:
#   sine: MSE = 0.4329
#   exp: MSE = 0.0658
#   polynomial: MSE = 0.8558
#   straight_line: MSE = 0.3035
# Average MSE across all families: 0.4145
#
# Block 66: Training on polynomial
#
# Block 67: Training on straight_line
#
# Block 68: Training on sine
#
# Block 69: Training on sine
#
# Block 70: Training on exp
#
# Evaluation at iteration 7000:
#   sine: MSE = 0.4653
#   exp: MSE = 0.0360
#   polynomial: MSE = 0.7790
#   straight_line: MSE = 0.1307
# Average MSE across all families: 0.3528
#
# Block 71: Training on exp
#
# Block 72: Training on sine
#
# Block 73: Training on sine
#
# Block 74: Training on straight_line
#
# Block 75: Training on polynomial
#
# Evaluation at iteration 7500:
#   sine: MSE = 0.4386
#   exp: MSE = 0.0717
#   polynomial: MSE = 0.7457
#   straight_line: MSE = 0.1009
# Average MSE across all families: 0.3392
#
# Block 76: Training on exp
#
# Block 77: Training on exp
#
# Block 78: Training on straight_line
#
# Block 79: Training on polynomial
#
# Block 80: Training on straight_line
#
# Evaluation at iteration 8000:
#   sine: MSE = 0.4590
#   exp: MSE = 0.0411
#   polynomial: MSE = 0.7205
#   straight_line: MSE = 0.0640
# Average MSE across all families: 0.3212
#
# Block 81: Training on straight_line
#
# Block 82: Training on polynomial
#
# Block 83: Training on sine
#
# Block 84: Training on polynomial
#
# Block 85: Training on sine
#
# Evaluation at iteration 8500:
#   sine: MSE = 0.4342
#   exp: MSE = 0.0825
#   polynomial: MSE = 0.7649
#   straight_line: MSE = 0.1481
# Average MSE across all families: 0.3574
#
# Block 86: Training on straight_line
#
# Block 87: Training on polynomial
#
# Block 88: Training on exp
#
# Block 89: Training on exp
#
# Block 90: Training on sine
#
# Evaluation at iteration 9000:
#   sine: MSE = 0.4387
#   exp: MSE = 0.0582
#   polynomial: MSE = 0.7725
#   straight_line: MSE = 0.1674
# Average MSE across all families: 0.3592
#
# Block 91: Training on polynomial
#
# Block 92: Training on sine
#
# Block 93: Training on exp
#
# Block 94: Training on polynomial
#
# Block 95: Training on exp
#
# Evaluation at iteration 9500:
#   sine: MSE = 0.4674
#   exp: MSE = 0.0320
#   polynomial: MSE = 0.7217
#   straight_line: MSE = 0.1227
# Average MSE across all families: 0.3359
#
# Block 96: Training on polynomial
#
# Block 97: Training on straight_line
#
# Block 98: Training on sine
#
# Block 99: Training on sine
#
# Block 100: Training on exp
#
# Evaluation at iteration 10000:
#   sine: MSE = 0.4786
#   exp: MSE = 0.0351
#   polynomial: MSE = 0.7877
#   straight_line: MSE = 0.1601
# Average MSE across all families: 0.3654
#
# Block 101: Training on exp
#
# Block 102: Training on sine
#
# Block 103: Training on sine
#
# Block 104: Training on sine
#
# Block 105: Training on sine
#
# Evaluation at iteration 10500:
#   sine: MSE = 0.4262
#   exp: MSE = 0.0817
#   polynomial: MSE = 0.8130
#   straight_line: MSE = 0.1838
# Average MSE across all families: 0.3762
#
# Block 106: Training on exp
#
# Block 107: Training on sine
#
# Block 108: Training on straight_line
#
# Block 109: Training on sine
#
# Block 110: Training on polynomial
#
# Evaluation at iteration 11000:
#   sine: MSE = 0.4310
#   exp: MSE = 0.0723
#   polynomial: MSE = 0.7347
#   straight_line: MSE = 0.1158
# Average MSE across all families: 0.3384
#
# Block 111: Training on sine
#
# Block 112: Training on sine
#
# Block 113: Training on sine
#
# Block 114: Training on exp
#
# Block 115: Training on exp
#
# Evaluation at iteration 11500:
#   sine: MSE = 0.4897
#   exp: MSE = 0.0256
#   polynomial: MSE = 0.7858
#   straight_line: MSE = 0.1357
# Average MSE across all families: 0.3592
#
# Block 116: Training on sine
#
# Block 117: Training on straight_line
#
# Block 118: Training on exp
#
# Block 119: Training on sine
#
# Block 120: Training on sine
#
# Evaluation at iteration 12000:
#   sine: MSE = 0.4196
#   exp: MSE = 0.0963
#   polynomial: MSE = 0.7774
#   straight_line: MSE = 0.1309
# Average MSE across all families: 0.3560
#
# Block 121: Training on straight_line
#
# Block 122: Training on sine
#
# Block 123: Training on polynomial
#
# Block 124: Training on sine
#
# Block 125: Training on exp
#
# Evaluation at iteration 12500:
#   sine: MSE = 0.4813
#   exp: MSE = 0.0241
#   polynomial: MSE = 0.7714
#   straight_line: MSE = 0.1365
# Average MSE across all families: 0.3533
#
# Block 126: Training on sine
#
# Block 127: Training on polynomial
#
# Block 128: Training on polynomial
#
# Block 129: Training on straight_line
#
# Block 130: Training on exp
#
# Evaluation at iteration 13000:
#   sine: MSE = 0.5549
#   exp: MSE = 0.0608
#   polynomial: MSE = 0.7589
#   straight_line: MSE = 0.1010
# Average MSE across all families: 0.3689
#
# Block 131: Training on sine
#
# Block 132: Training on straight_line
#
# Block 133: Training on sine
#
# Block 134: Training on sine
#
# Block 135: Training on straight_line
#
# Evaluation at iteration 13500:
#   sine: MSE = 0.4558
#   exp: MSE = 0.0322
#   polynomial: MSE = 0.7248
#   straight_line: MSE = 0.0507
# Average MSE across all families: 0.3159
#
# Block 136: Training on exp
#
# Block 137: Training on polynomial
#
# Block 138: Training on polynomial
#
# Block 139: Training on straight_line
#
# Block 140: Training on exp
#
# Evaluation at iteration 14000:
#   sine: MSE = 0.4761
#   exp: MSE = 0.0241
#   polynomial: MSE = 0.7168
#   straight_line: MSE = 0.0570
# Average MSE across all families: 0.3185
#
# Block 141: Training on exp
#
# Block 142: Training on sine
#
# Block 143: Training on exp
#
# Block 144: Training on exp
#
# Block 145: Training on polynomial
#
# Evaluation at iteration 14500:
#   sine: MSE = 0.4410
#   exp: MSE = 0.1045
#   polynomial: MSE = 0.7578
#   straight_line: MSE = 0.1296
# Average MSE across all families: 0.3582
#
# Block 146: Training on polynomial
#
# Block 147: Training on sine
#
# Block 148: Training on straight_line
#
# Block 149: Training on exp
#
# Block 150: Training on sine
#
# Evaluation at iteration 15000:
#   sine: MSE = 0.4253
#   exp: MSE = 0.0493
#   polynomial: MSE = 0.7536
#   straight_line: MSE = 0.1281
# Average MSE across all families: 0.3391
#
# Block 151: Training on straight_line
#
# Block 152: Training on straight_line
#
# Block 153: Training on polynomial
#
# Block 154: Training on polynomial
#
# Block 155: Training on straight_line
#
# Evaluation at iteration 15500:
#   sine: MSE = 0.4707
#   exp: MSE = 0.0345
#   polynomial: MSE = 0.6944
#   straight_line: MSE = 0.0572
# Average MSE across all families: 0.3142
#
# Block 156: Training on polynomial
#
# Block 157: Training on exp
#
# Block 158: Training on sine
#
# Block 159: Training on straight_line
#
# Block 160: Training on sine
#
# Evaluation at iteration 16000:
#   sine: MSE = 0.4431
#   exp: MSE = 0.0413
#   polynomial: MSE = 0.7426
#   straight_line: MSE = 0.0850
# Average MSE across all families: 0.3280
#
# Block 161: Training on polynomial
#
# Block 162: Training on sine
#
# Block 163: Training on polynomial
#
# Block 164: Training on exp
#
# Block 165: Training on exp
#
# Evaluation at iteration 16500:
#   sine: MSE = 0.4692
#   exp: MSE = 0.0256
#   polynomial: MSE = 0.6973
#   straight_line: MSE = 0.0942
# Average MSE across all families: 0.3216
#
# Block 166: Training on straight_line
#
# Block 167: Training on polynomial
#
# Block 168: Training on polynomial
#
# Block 169: Training on polynomial
#
# Block 170: Training on exp
#
# Evaluation at iteration 17000:
#   sine: MSE = 0.4739
#   exp: MSE = 0.0232
#   polynomial: MSE = 0.6566
#   straight_line: MSE = 0.0863
# Average MSE across all families: 0.3100
#
# Block 171: Training on polynomial
#
# Block 172: Training on straight_line
#
# Block 173: Training on straight_line
#
# Block 174: Training on sine
#
# Block 175: Training on sine
#
# Evaluation at iteration 17500:
#   sine: MSE = 0.4366
#   exp: MSE = 0.0490
#   polynomial: MSE = 0.7435
#   straight_line: MSE = 0.1236
# Average MSE across all families: 0.3382
#
# Block 176: Training on exp
#
# Block 177: Training on polynomial
#
# Block 178: Training on exp
#
# Block 179: Training on exp
#
# Block 180: Training on exp
#
# Evaluation at iteration 18000:
#   sine: MSE = 0.4848
#   exp: MSE = 0.0240
#   polynomial: MSE = 0.7264
#   straight_line: MSE = 0.1433
# Average MSE across all families: 0.3446
#
# Block 181: Training on straight_line
#
# Block 182: Training on straight_line
#
# Block 183: Training on straight_line
#
# Block 184: Training on sine
#
# Block 185: Training on straight_line
#
# Evaluation at iteration 18500:
#   sine: MSE = 0.4571
#   exp: MSE = 0.0376
#   polynomial: MSE = 0.7218
#   straight_line: MSE = 0.0348
# Average MSE across all families: 0.3128
#
# Block 186: Training on straight_line
#
# Block 187: Training on sine
#
# Block 188: Training on exp
#
# Block 189: Training on straight_line
#
# Block 190: Training on sine
#
# Evaluation at iteration 19000:
#   sine: MSE = 0.4382
#   exp: MSE = 0.0444
#   polynomial: MSE = 0.7415
#   straight_line: MSE = 0.0602
# Average MSE across all families: 0.3211
#
# Block 191: Training on polynomial
#
# Block 192: Training on exp
#
# Block 193: Training on straight_line
#
# Block 194: Training on straight_line
#
# Block 195: Training on sine
#
# Evaluation at iteration 19500:
#   sine: MSE = 0.4360
#   exp: MSE = 0.0460
#   polynomial: MSE = 0.7190
#   straight_line: MSE = 0.0464
# Average MSE across all families: 0.3118
#
# Block 196: Training on sine
#
# Block 197: Training on straight_line
#
# Block 198: Training on polynomial
#
# Block 199: Training on polynomial
#
# Block 200: Training on straight_line
#
# Evaluation at iteration 20000:
#   sine: MSE = 0.4635
#   exp: MSE = 0.0355
#   polynomial: MSE = 0.6783
#   straight_line: MSE = 0.0360
# Average MSE across all families: 0.3033
#
# Block 201: Training on sine
#
# Block 202: Training on straight_line
#
# Block 203: Training on exp
#
# Block 204: Training on sine
#
# Block 205: Training on exp
#
# Evaluation at iteration 20500:
#   sine: MSE = 0.4692
#   exp: MSE = 0.0234
#   polynomial: MSE = 0.7478
#   straight_line: MSE = 0.1027
# Average MSE across all families: 0.3358
#
# Block 206: Training on sine
#
# Block 207: Training on straight_line
#
# Block 208: Training on straight_line
#
# Block 209: Training on polynomial
#
# Block 210: Training on sine
#
# Evaluation at iteration 21000:
#   sine: MSE = 0.4318
#   exp: MSE = 0.0584
#   polynomial: MSE = 0.6929
#   straight_line: MSE = 0.0988
# Average MSE across all families: 0.3205
#
# Block 211: Training on exp
#
# Block 212: Training on sine
#
# Block 213: Training on sine
#
# Block 214: Training on sine
#
# Block 215: Training on exp
#
# Evaluation at iteration 21500:
#   sine: MSE = 0.4657
#   exp: MSE = 0.0222
#   polynomial: MSE = 0.8146
#   straight_line: MSE = 0.1756
# Average MSE across all families: 0.3695
#
# Block 216: Training on sine
#
# Block 217: Training on exp
#
# Block 218: Training on polynomial
#
# Block 219: Training on polynomial
#
# Block 220: Training on exp
#
# Evaluation at iteration 22000:
#   sine: MSE = 0.4433
#   exp: MSE = 0.0253
#   polynomial: MSE = 0.6688
#   straight_line: MSE = 0.1432
# Average MSE across all families: 0.3201
#
# Block 221: Training on sine
#
# Block 222: Training on straight_line
#
# Block 223: Training on straight_line
#
# Block 224: Training on sine
#
# Block 225: Training on sine
#
# Evaluation at iteration 22500:
#   sine: MSE = 0.3931
#   exp: MSE = 0.0680
#   polynomial: MSE = 0.7399
#   straight_line: MSE = 0.0905
# Average MSE across all families: 0.3229
#
# Block 226: Training on polynomial
#
# Block 227: Training on straight_line
#
# Block 228: Training on sine
#
# Block 229: Training on polynomial
#
# Block 230: Training on exp
#
# Evaluation at iteration 23000:
#   sine: MSE = 0.4343
#   exp: MSE = 0.0258
#   polynomial: MSE = 0.6715
#   straight_line: MSE = 0.1012
# Average MSE across all families: 0.3082
#
# Block 231: Training on polynomial
#
# Block 232: Training on sine
#
# Block 233: Training on exp
#
# Block 234: Training on polynomial
#
# Block 235: Training on sine
#
# Evaluation at iteration 23500:
#   sine: MSE = 0.4001
#   exp: MSE = 0.0629
#   polynomial: MSE = 0.6090
#   straight_line: MSE = 0.1092
# Average MSE across all families: 0.2953
#
# Block 236: Training on sine
#
# Block 237: Training on sine
#
# Block 238: Training on exp
#
# Block 239: Training on polynomial
#
# Block 240: Training on polynomial
#
# Evaluation at iteration 24000:
#   sine: MSE = 0.4239
#   exp: MSE = 0.0719
#   polynomial: MSE = 0.5224
#   straight_line: MSE = 0.1250
# Average MSE across all families: 0.2858
#
# Block 241: Training on polynomial
#
# Block 242: Training on sine
#
# Block 243: Training on straight_line
#
# Block 244: Training on straight_line
#
# Block 245: Training on straight_line
#
# Evaluation at iteration 24500:
#   sine: MSE = 0.3980
#   exp: MSE = 0.0382
#   polynomial: MSE = 0.6896
#   straight_line: MSE = 0.0417
# Average MSE across all families: 0.2919
#
# Block 246: Training on polynomial
#
# Block 247: Training on exp
#
# Block 248: Training on exp
#
# Block 249: Training on straight_line
#
# Block 250: Training on polynomial
#
# Evaluation at iteration 25000:
#   sine: MSE = 0.3978
#   exp: MSE = 0.0767
#   polynomial: MSE = 0.5894
#   straight_line: MSE = 0.1044
# Average MSE across all families: 0.2921
#
# Block 251: Training on sine
#
# Block 252: Training on exp
#
# Block 253: Training on exp
#
# Block 254: Training on polynomial
#
# Block 255: Training on polynomial
#
# Evaluation at iteration 25500:
#   sine: MSE = 0.4349
#   exp: MSE = 0.0615
#   polynomial: MSE = 0.4881
#   straight_line: MSE = 0.1579
# Average MSE across all families: 0.2856
#
# Block 256: Training on polynomial
#
# Block 257: Training on polynomial
#
# Block 258: Training on sine
#
# Block 259: Training on polynomial
#
# Block 260: Training on sine
#
# Evaluation at iteration 26000:
#   sine: MSE = 0.3677
#   exp: MSE = 0.0880
#   polynomial: MSE = 0.5024
#   straight_line: MSE = 0.1513
# Average MSE across all families: 0.2773
#
# Block 261: Training on sine
#
# Block 262: Training on polynomial
#
# Block 263: Training on exp
#
# Block 264: Training on exp
#
# Block 265: Training on polynomial
#
# Evaluation at iteration 26500:
#   sine: MSE = 0.3980
#   exp: MSE = 0.0632
#   polynomial: MSE = 0.4446
#   straight_line: MSE = 0.1339
# Average MSE across all families: 0.2599
#
# Block 266: Training on polynomial
#
# Block 267: Training on straight_line
#
# Block 268: Training on exp
#
# Block 269: Training on polynomial
#
# Block 270: Training on sine
#
# Evaluation at iteration 27000:
#   sine: MSE = 0.3630
#   exp: MSE = 0.0734
#   polynomial: MSE = 0.4936
#   straight_line: MSE = 0.1454
# Average MSE across all families: 0.2688
#
# Block 271: Training on straight_line
#
# Block 272: Training on exp
#
# Block 273: Training on sine
#
# Block 274: Training on polynomial
#
# Block 275: Training on exp
#
# Evaluation at iteration 27500:
#   sine: MSE = 0.4058
#   exp: MSE = 0.0238
#   polynomial: MSE = 0.5200
#   straight_line: MSE = 0.0901
# Average MSE across all families: 0.2599
#
# Block 276: Training on sine
#
# Block 277: Training on polynomial
#
# Block 278: Training on straight_line
#
# Block 279: Training on polynomial
#
# Block 280: Training on polynomial
#
# Evaluation at iteration 28000:
#   sine: MSE = 0.3956
#   exp: MSE = 0.0626
#   polynomial: MSE = 0.4101
#   straight_line: MSE = 0.1455
# Average MSE across all families: 0.2535
#
# Block 281: Training on straight_line
#
# Block 282: Training on sine
#
# Block 283: Training on sine
#
# Block 284: Training on straight_line
#
# Block 285: Training on straight_line
#
# Evaluation at iteration 28500:
#   sine: MSE = 0.3799
#   exp: MSE = 0.0310
#   polynomial: MSE = 0.5918
#   straight_line: MSE = 0.0372
# Average MSE across all families: 0.2600
#
# Block 286: Training on polynomial
#
# Block 287: Training on polynomial
#
# Block 288: Training on sine
#
# Block 289: Training on straight_line
#
# Block 290: Training on sine
#
# Evaluation at iteration 29000:
#   sine: MSE = 0.3338
#   exp: MSE = 0.0529
#   polynomial: MSE = 0.5799
#   straight_line: MSE = 0.0522
# Average MSE across all families: 0.2547
#
# Block 291: Training on straight_line
#
# Block 292: Training on straight_line
#
# Block 293: Training on sine
#
# Block 294: Training on polynomial
#
# Block 295: Training on polynomial
#
# Evaluation at iteration 29500:
#   sine: MSE = 0.3575
#   exp: MSE = 0.0678
#   polynomial: MSE = 0.4194
#   straight_line: MSE = 0.1160
# Average MSE across all families: 0.2402
#
# Block 296: Training on exp
#
# Block 297: Training on exp
#
# Block 298: Training on straight_line
#
# Block 299: Training on sine
#
# Block 300: Training on sine
#
# Evaluation at iteration 30000:
#   sine: MSE = 0.3175
#   exp: MSE = 0.0758
#   polynomial: MSE = 0.6436
#   straight_line: MSE = 0.0798
# Average MSE across all families: 0.2792
#
# Block 301: Training on sine
#
# Block 302: Training on exp
#
# Block 303: Training on exp
#
# Block 304: Training on sine
#
# Block 305: Training on straight_line
#
# Evaluation at iteration 30500:
#   sine: MSE = 0.4299
#   exp: MSE = 0.0369
#   polynomial: MSE = 0.6458
#   straight_line: MSE = 0.1165
# Average MSE across all families: 0.3073
#
# Block 306: Training on sine
#
# Block 307: Training on sine
#
# Block 308: Training on straight_line
#
# Block 309: Training on polynomial
#
# Block 310: Training on straight_line
#
# Evaluation at iteration 31000:
#   sine: MSE = 0.3432
#   exp: MSE = 0.0370
#   polynomial: MSE = 0.6151
#   straight_line: MSE = 0.0443
# Average MSE across all families: 0.2599
#
# Block 311: Training on straight_line
#
# Block 312: Training on exp
#
# Block 313: Training on straight_line
#
# Block 314: Training on sine
#
# Block 315: Training on polynomial
#
# Evaluation at iteration 31500:
#   sine: MSE = 0.3447
#   exp: MSE = 0.0625
#   polynomial: MSE = 0.4759
#   straight_line: MSE = 0.1011
# Average MSE across all families: 0.2461
#
# Block 316: Training on exp
#
# Block 317: Training on polynomial
#
# Block 318: Training on exp
#
# Block 319: Training on straight_line
#
# Block 320: Training on exp
#
# Evaluation at iteration 32000:
#   sine: MSE = 0.3895
#   exp: MSE = 0.0193
#   polynomial: MSE = 0.5995
#   straight_line: MSE = 0.0370
# Average MSE across all families: 0.2613
#
# Block 321: Training on polynomial
#
# Block 322: Training on sine
#
# Block 323: Training on sine
#
# Block 324: Training on sine
#
# Block 325: Training on straight_line
#
# Evaluation at iteration 32500:
#   sine: MSE = 0.3342
#   exp: MSE = 0.0401
#   polynomial: MSE = 0.5774
#   straight_line: MSE = 0.0345
# Average MSE across all families: 0.2465
#
# Block 326: Training on exp
#
# Block 327: Training on sine
#
# Block 328: Training on straight_line
#
# Block 329: Training on straight_line
#
# Block 330: Training on polynomial
#
# Evaluation at iteration 33000:
#   sine: MSE = 0.3577
#   exp: MSE = 0.0610
#   polynomial: MSE = 0.4460
#   straight_line: MSE = 0.1073
# Average MSE across all families: 0.2430
#
# Block 331: Training on exp
#
# Block 332: Training on sine
#
# Block 333: Training on exp
#
# Block 334: Training on exp
#
# Block 335: Training on sine
#
# Evaluation at iteration 33500:
#   sine: MSE = 0.3158
#   exp: MSE = 0.0667
#   polynomial: MSE = 0.5865
#   straight_line: MSE = 0.0855
# Average MSE across all families: 0.2636
#
# Block 336: Training on exp
#
# Block 337: Training on straight_line
#
# Block 338: Training on straight_line
#
# Block 339: Training on polynomial
#
# Block 340: Training on exp
#
# Evaluation at iteration 34000:
#   sine: MSE = 0.3894
#   exp: MSE = 0.0218
#   polynomial: MSE = 0.5105
#   straight_line: MSE = 0.1101
# Average MSE across all families: 0.2579
#
# Block 341: Training on sine
#
# Block 342: Training on straight_line
#
# Block 343: Training on exp
#
# Block 344: Training on straight_line
#
# Block 345: Training on straight_line
#
# Evaluation at iteration 34500:
#   sine: MSE = 0.3956
#   exp: MSE = 0.0439
#   polynomial: MSE = 0.6901
#   straight_line: MSE = 0.0542
# Average MSE across all families: 0.2959
#
# Block 346: Training on straight_line
#
# Block 347: Training on polynomial
#
# Block 348: Training on straight_line
#
# Block 349: Training on straight_line
#
# Block 350: Training on exp
#
# Evaluation at iteration 35000:
#   sine: MSE = 0.4212
#   exp: MSE = 0.0208
#   polynomial: MSE = 0.6538
#   straight_line: MSE = 0.0280
# Average MSE across all families: 0.2809
#
# Block 351: Training on exp
#
# Block 352: Training on sine
#
# Block 353: Training on polynomial
#
# Block 354: Training on polynomial
#
# Block 355: Training on polynomial
#
# Evaluation at iteration 35500:
#   sine: MSE = 0.3669
#   exp: MSE = 0.0599
#   polynomial: MSE = 0.3749
#   straight_line: MSE = 0.1538
# Average MSE across all families: 0.2389
#
# Block 356: Training on sine
#
# Block 357: Training on exp
#
# Block 358: Training on polynomial
#
# Block 359: Training on exp
#
# Block 360: Training on straight_line
#
# Evaluation at iteration 36000:
#   sine: MSE = 0.3810
#   exp: MSE = 0.0262
#   polynomial: MSE = 0.5647
#   straight_line: MSE = 0.0299
# Average MSE across all families: 0.2505
#
# Block 361: Training on polynomial
#
# Block 362: Training on straight_line
#
# Block 363: Training on sine
#
# Block 364: Training on sine
#
# Block 365: Training on sine
#
# Evaluation at iteration 36500:
#   sine: MSE = 0.2988
#   exp: MSE = 0.0766
#   polynomial: MSE = 0.5732
#   straight_line: MSE = 0.0699
# Average MSE across all families: 0.2546
#
# Block 366: Training on sine
#
# Block 367: Training on exp
#
# Block 368: Training on exp
#
# Block 369: Training on sine
#
# Block 370: Training on polynomial
#
# Evaluation at iteration 37000:
#   sine: MSE = 0.3414
#   exp: MSE = 0.0497
#   polynomial: MSE = 0.3852
#   straight_line: MSE = 0.1051
# Average MSE across all families: 0.2203
#
# Block 371: Training on sine
#
# Block 372: Training on straight_line
#
# Block 373: Training on polynomial
#
# Block 374: Training on exp
#
# Block 375: Training on exp
#
# Evaluation at iteration 37500:
#   sine: MSE = 0.3852
#   exp: MSE = 0.0200
#   polynomial: MSE = 0.4546
#   straight_line: MSE = 0.0933
# Average MSE across all families: 0.2383
#
# Block 376: Training on straight_line
#
# Block 377: Training on polynomial
#
# Block 378: Training on straight_line
#
# Block 379: Training on sine
#
# Block 380: Training on sine
#
# Evaluation at iteration 38000:
#   sine: MSE = 0.3077
#   exp: MSE = 0.0721
#   polynomial: MSE = 0.5889
#   straight_line: MSE = 0.0745
# Average MSE across all families: 0.2608
#
# Block 381: Training on sine
#
# Block 382: Training on straight_line
#
# Block 383: Training on exp
#
# Block 384: Training on polynomial
#
# Block 385: Training on straight_line
#
# Evaluation at iteration 38500:
#   sine: MSE = 0.3542
#   exp: MSE = 0.0393
#   polynomial: MSE = 0.5584
#   straight_line: MSE = 0.0371
# Average MSE across all families: 0.2472
#
# Block 386: Training on straight_line
#
# Block 387: Training on straight_line
#
# Block 388: Training on exp
#
# Block 389: Training on sine
#
# Block 390: Training on sine
#
# Evaluation at iteration 39000:
#   sine: MSE = 0.3062
#   exp: MSE = 0.0696
#   polynomial: MSE = 0.6043
#   straight_line: MSE = 0.0712
# Average MSE across all families: 0.2628
#
# Block 391: Training on exp
#
# Block 392: Training on polynomial
#
# Block 393: Training on polynomial
#
# Block 394: Training on polynomial
#
# Block 395: Training on sine
#
# Evaluation at iteration 39500:
#   sine: MSE = 0.3082
#   exp: MSE = 0.0618
#   polynomial: MSE = 0.3838
#   straight_line: MSE = 0.1153
# Average MSE across all families: 0.2173
#
# Block 396: Training on straight_line
#
# Block 397: Training on polynomial
#
# Block 398: Training on polynomial
#
# Block 399: Training on straight_line
#
# Block 400: Training on straight_line
#
# Evaluation at iteration 40000:
#   sine: MSE = 0.3617
#   exp: MSE = 0.0322
#   polynomial: MSE = 0.5712
#   straight_line: MSE = 0.0335
# Average MSE across all families: 0.2497
#
# Block 401: Training on straight_line
#
# Block 402: Training on sine
#
# Block 403: Training on exp
#
# Block 404: Training on exp
#
# Block 405: Training on exp
#
# Evaluation at iteration 40500:
#   sine: MSE = 0.3837
#   exp: MSE = 0.0190
#   polynomial: MSE = 0.6169
#   straight_line: MSE = 0.0411
# Average MSE across all families: 0.2652
#
# Block 406: Training on polynomial
#
# Block 407: Training on polynomial
#
# Block 408: Training on sine
#
# Block 409: Training on sine
#
# Block 410: Training on straight_line
#
# Evaluation at iteration 41000:
#   sine: MSE = 0.3441
#   exp: MSE = 0.0390
#   polynomial: MSE = 0.5286
#   straight_line: MSE = 0.0485
# Average MSE across all families: 0.2401
#
# Block 411: Training on straight_line
#
# Block 412: Training on exp
#
# Block 413: Training on straight_line
#
# Block 414: Training on sine
#
# Block 415: Training on exp
#
# Evaluation at iteration 41500:
#   sine: MSE = 0.3713
#   exp: MSE = 0.0185
#   polynomial: MSE = 0.6350
#   straight_line: MSE = 0.0456
# Average MSE across all families: 0.2676
#
# Block 416: Training on polynomial
#
# Block 417: Training on straight_line
#
# Block 418: Training on sine
#
# Block 419: Training on straight_line
#
# Block 420: Training on straight_line
#
# Evaluation at iteration 42000:
#   sine: MSE = 0.3785
#   exp: MSE = 0.0268
#   polynomial: MSE = 0.6078
#   straight_line: MSE = 0.0270
# Average MSE across all families: 0.2600
#
# Block 421: Training on straight_line
#
# Block 422: Training on sine
#
# Block 423: Training on sine
#
# Block 424: Training on straight_line
#
# Block 425: Training on exp
#
# Evaluation at iteration 42500:
#   sine: MSE = 0.3776
#   exp: MSE = 0.0175
#   polynomial: MSE = 0.5982
#   straight_line: MSE = 0.0407
# Average MSE across all families: 0.2585
#
# Block 426: Training on sine
#
# Block 427: Training on sine
#
# Block 428: Training on exp
#
# Block 429: Training on polynomial
#
# Block 430: Training on sine
#
# Evaluation at iteration 43000:
#   sine: MSE = 0.2896
#   exp: MSE = 0.0546
#   polynomial: MSE = 0.4416
#   straight_line: MSE = 0.0865
# Average MSE across all families: 0.2181
#
# Block 431: Training on polynomial
#
# Block 432: Training on exp
#
# Block 433: Training on straight_line
#
# Block 434: Training on straight_line
#
# Block 435: Training on sine
#
# Evaluation at iteration 43500:
#   sine: MSE = 0.2997
#   exp: MSE = 0.0726
#   polynomial: MSE = 0.6318
#   straight_line: MSE = 0.0531
# Average MSE across all families: 0.2643
#
# Block 436: Training on sine
#
# Block 437: Training on straight_line
#
# Block 438: Training on polynomial
#
# Block 439: Training on sine
#
# Block 440: Training on polynomial
#
# Evaluation at iteration 44000:
#   sine: MSE = 0.3147
#   exp: MSE = 0.0624
#   polynomial: MSE = 0.3440
#   straight_line: MSE = 0.1054
# Average MSE across all families: 0.2066
#
# Block 441: Training on exp
#
# Block 442: Training on straight_line
#
# Block 443: Training on polynomial
#
# Block 444: Training on sine
#
# Block 445: Training on exp
#
# Evaluation at iteration 44500:
#   sine: MSE = 0.3383
#   exp: MSE = 0.0213
#   polynomial: MSE = 0.4723
#   straight_line: MSE = 0.0981
# Average MSE across all families: 0.2325
#
# Block 446: Training on sine
#
# Block 447: Training on straight_line
#
# Block 448: Training on straight_line
#
# Block 449: Training on polynomial
#
# Block 450: Training on exp
#
# Evaluation at iteration 45000:
#   sine: MSE = 0.3676
#   exp: MSE = 0.0214
#   polynomial: MSE = 0.4186
#   straight_line: MSE = 0.0645
# Average MSE across all families: 0.2180
#
# Block 451: Training on straight_line
#
# Block 452: Training on polynomial
#
# Block 453: Training on sine
#
# Block 454: Training on sine
#
# Block 455: Training on sine
#
# Evaluation at iteration 45500:
#   sine: MSE = 0.2775
#   exp: MSE = 0.0846
#   polynomial: MSE = 0.4282
#   straight_line: MSE = 0.1113
# Average MSE across all families: 0.2254
#
# Block 456: Training on straight_line
#
# Block 457: Training on polynomial
#
# Block 458: Training on sine
#
# Block 459: Training on exp
#
# Block 460: Training on exp
#
# Evaluation at iteration 46000:
#   sine: MSE = 0.3568
#   exp: MSE = 0.0181
#   polynomial: MSE = 0.4754
#   straight_line: MSE = 0.0848
# Average MSE across all families: 0.2338
#
# Block 461: Training on sine
#
# Block 462: Training on straight_line
#
# Block 463: Training on polynomial
#
# Block 464: Training on sine
#
# Block 465: Training on exp
#
# Evaluation at iteration 46500:
#   sine: MSE = 0.3427
#   exp: MSE = 0.0188
#   polynomial: MSE = 0.4450
#   straight_line: MSE = 0.0961
# Average MSE across all families: 0.2256
#
# Block 466: Training on straight_line
#
# Block 467: Training on straight_line
#
# Block 468: Training on sine
#
# Block 469: Training on sine
#
# Block 470: Training on straight_line
#
# Evaluation at iteration 47000:
#   sine: MSE = 0.3447
#   exp: MSE = 0.0261
#   polynomial: MSE = 0.5530
#   straight_line: MSE = 0.0230
# Average MSE across all families: 0.2367
#
# Block 471: Training on sine
#
# Block 472: Training on sine
#
# Block 473: Training on straight_line
#
# Block 474: Training on exp
#
# Block 475: Training on sine
#
# Evaluation at iteration 47500:
#   sine: MSE = 0.2876
#   exp: MSE = 0.0453
#   polynomial: MSE = 0.5672
#   straight_line: MSE = 0.0512
# Average MSE across all families: 0.2378
#
# Block 476: Training on straight_line
#
# Block 477: Training on straight_line
#
# Block 478: Training on straight_line
#
# Block 479: Training on sine
#
# Block 480: Training on straight_line
#
# Evaluation at iteration 48000:
#   sine: MSE = 0.3221
#   exp: MSE = 0.0464
#   polynomial: MSE = 0.5751
#   straight_line: MSE = 0.0299
# Average MSE across all families: 0.2434
#
# Block 481: Training on polynomial
#
# Block 482: Training on polynomial
#
# Block 483: Training on sine
#
# Block 484: Training on polynomial
#
# Block 485: Training on sine
#
# Evaluation at iteration 48500:
#   sine: MSE = 0.2820
#   exp: MSE = 0.0581
#   polynomial: MSE = 0.3823
#   straight_line: MSE = 0.0907
# Average MSE across all families: 0.2033
#
# Block 486: Training on sine
#
# Block 487: Training on polynomial
#
# Block 488: Training on sine
#
# Block 489: Training on polynomial
#
# Block 490: Training on polynomial
#
# Evaluation at iteration 49000:
#   sine: MSE = 0.2969
#   exp: MSE = 0.0792
#   polynomial: MSE = 0.3201
#   straight_line: MSE = 0.1124
# Average MSE across all families: 0.2022
#
# Block 491: Training on exp
#
# Block 492: Training on sine
#
# Block 493: Training on exp
#
# Block 494: Training on polynomial
#
# Block 495: Training on sine
#
# Evaluation at iteration 49500:
#   sine: MSE = 0.2809
#   exp: MSE = 0.0762
#   polynomial: MSE = 0.3661
#   straight_line: MSE = 0.1232
# Average MSE across all families: 0.2116
#
# Block 496: Training on exp
#
# Block 497: Training on exp
#
# Block 498: Training on sine
#
# Block 499: Training on exp
#
# Block 500: Training on sine
#
# Evaluation at iteration 50000:
#   sine: MSE = 0.2642
#   exp: MSE = 0.0521
#   polynomial: MSE = 0.4378
#   straight_line: MSE = 0.0595
# Average MSE across all families: 0.2034
#
# Block 501: Training on sine
#
# Block 502: Training on polynomial
#
# Block 503: Training on polynomial
#
# Block 504: Training on sine
#
# Block 505: Training on exp
#
# Evaluation at iteration 50500:
#   sine: MSE = 0.3460
#   exp: MSE = 0.0175
#   polynomial: MSE = 0.4663
#   straight_line: MSE = 0.0998
# Average MSE across all families: 0.2324
#
# Block 506: Training on exp
#
# Block 507: Training on exp
#
# Block 508: Training on straight_line
#
# Block 509: Training on sine
#
# Block 510: Training on straight_line
#
# Evaluation at iteration 51000:
#   sine: MSE = 0.3245
#   exp: MSE = 0.0297
#   polynomial: MSE = 0.5617
#   straight_line: MSE = 0.0282
# Average MSE across all families: 0.2360
#
# Block 511: Training on polynomial
#
# Block 512: Training on polynomial
#
# Block 513: Training on exp
#
# Block 514: Training on sine
#
# Block 515: Training on exp
#
# Evaluation at iteration 51500:
#   sine: MSE = 0.3285
#   exp: MSE = 0.0163
#   polynomial: MSE = 0.4344
#   straight_line: MSE = 0.0866
# Average MSE across all families: 0.2165
#
# Block 516: Training on polynomial
#
# Block 517: Training on polynomial
#
# Block 518: Training on straight_line
#
# Block 519: Training on polynomial
#
# Block 520: Training on polynomial
#
# Evaluation at iteration 52000:
#   sine: MSE = 0.3026
#   exp: MSE = 0.0524
#   polynomial: MSE = 0.2939
#   straight_line: MSE = 0.1141
# Average MSE across all families: 0.1908
#
# Block 521: Training on polynomial
#
# Block 522: Training on exp
#
# Block 523: Training on sine
#
# Block 524: Training on sine
#
# Block 525: Training on polynomial
#
# Evaluation at iteration 52500:
#   sine: MSE = 0.3148
#   exp: MSE = 0.0510
#   polynomial: MSE = 0.2925
#   straight_line: MSE = 0.1505
# Average MSE across all families: 0.2022
#
# Block 526: Training on exp
#
# Block 527: Training on straight_line
#
# Block 528: Training on exp
#
# Block 529: Training on exp
#
# Block 530: Training on exp
#
# Evaluation at iteration 53000:
#   sine: MSE = 0.3903
#   exp: MSE = 0.0133
#   polynomial: MSE = 0.5340
#   straight_line: MSE = 0.0394
# Average MSE across all families: 0.2442
#
# Block 531: Training on polynomial
#
# Block 532: Training on exp
#
# Block 533: Training on exp
#
# Block 534: Training on exp
#
# Block 535: Training on polynomial
#
# Evaluation at iteration 53500:
#   sine: MSE = 0.3500
#   exp: MSE = 0.0434
#   polynomial: MSE = 0.3126
#   straight_line: MSE = 0.1245
# Average MSE across all families: 0.2076
#
# Block 536: Training on polynomial
#
# Block 537: Training on straight_line
#
# Block 538: Training on sine
#
# Block 539: Training on exp
#
# Block 540: Training on sine
#
# Evaluation at iteration 54000:
#   sine: MSE = 0.2819
#   exp: MSE = 0.0386
#   polynomial: MSE = 0.4697
#   straight_line: MSE = 0.0502
# Average MSE across all families: 0.2101
#
# Block 541: Training on straight_line
#
# Block 542: Training on sine
#
# Block 543: Training on sine
#
# Block 544: Training on exp
#
# Block 545: Training on straight_line
#
# Evaluation at iteration 54500:
#   sine: MSE = 0.3049
#   exp: MSE = 0.1003
#   polynomial: MSE = 0.5378
#   straight_line: MSE = 0.0613
# Average MSE across all families: 0.2511
#
# Block 546: Training on polynomial
#
# Block 547: Training on straight_line
#
# Block 548: Training on exp
#
# Block 549: Training on straight_line
#
# Block 550: Training on polynomial
#
# Evaluation at iteration 55000:
#   sine: MSE = 0.3184
#   exp: MSE = 0.0423
#   polynomial: MSE = 0.3419
#   straight_line: MSE = 0.0784
# Average MSE across all families: 0.1953
#
# Block 551: Training on polynomial
#
# Block 552: Training on sine
#
# Block 553: Training on exp
#
# Block 554: Training on straight_line
#
# Block 555: Training on polynomial
#
# Evaluation at iteration 55500:
#   sine: MSE = 0.3224
#   exp: MSE = 0.0456
#   polynomial: MSE = 0.3248
#   straight_line: MSE = 0.0802
# Average MSE across all families: 0.1933
#
# Block 556: Training on sine
#
# Block 557: Training on straight_line
#
# Block 558: Training on straight_line
#
# Block 559: Training on sine
#
# Block 560: Training on straight_line
#
# Evaluation at iteration 56000:
#   sine: MSE = 0.3392
#   exp: MSE = 0.0233
#   polynomial: MSE = 0.5167
#   straight_line: MSE = 0.0229
# Average MSE across all families: 0.2255
#
# Block 561: Training on polynomial
#
# Block 562: Training on straight_line
#
# Block 563: Training on exp
#
# Block 564: Training on polynomial
#
# Block 565: Training on polynomial
#
# Evaluation at iteration 56500:
#   sine: MSE = 0.3086
#   exp: MSE = 0.0591
#   polynomial: MSE = 0.2934
#   straight_line: MSE = 0.1186
# Average MSE across all families: 0.1950
#
# Block 566: Training on straight_line
#
# Block 567: Training on sine
#
# Block 568: Training on exp
#
# Block 569: Training on sine
#
# Block 570: Training on polynomial
#
# Evaluation at iteration 57000:
#   sine: MSE = 0.2958
#   exp: MSE = 0.0582
#   polynomial: MSE = 0.2889
#   straight_line: MSE = 0.1105
# Average MSE across all families: 0.1883
#
# Block 571: Training on sine
#
# Block 572: Training on exp
#
# Block 573: Training on straight_line
#
# Block 574: Training on straight_line
#
# Block 575: Training on exp
#
# Evaluation at iteration 57500:
#   sine: MSE = 0.3800
#   exp: MSE = 0.0137
#   polynomial: MSE = 0.5476
#   straight_line: MSE = 0.0334
# Average MSE across all families: 0.2437
#
# Block 576: Training on straight_line
#
# Block 577: Training on straight_line
#
# Block 578: Training on exp
#
# Block 579: Training on exp
#
# Block 580: Training on straight_line
#
# Evaluation at iteration 58000:
#   sine: MSE = 0.4111
#   exp: MSE = 0.0229
#   polynomial: MSE = 0.5974
#   straight_line: MSE = 0.0223
# Average MSE across all families: 0.2634
#
# Block 581: Training on polynomial
#
# Block 582: Training on exp
#
# Block 583: Training on polynomial
#
# Block 584: Training on straight_line
#
# Block 585: Training on sine
#
# Evaluation at iteration 58500:
#   sine: MSE = 0.2891
#   exp: MSE = 0.0529
#   polynomial: MSE = 0.4869
#   straight_line: MSE = 0.0410
# Average MSE across all families: 0.2175
#
# Block 586: Training on straight_line
#
# Block 587: Training on exp
#
# Block 588: Training on polynomial
#
# Block 589: Training on sine
#
# Block 590: Training on straight_line
#
# Evaluation at iteration 59000:
#   sine: MSE = 0.3179
#   exp: MSE = 0.0271
#   polynomial: MSE = 0.4544
#   straight_line: MSE = 0.0233
# Average MSE across all families: 0.2057
#
# Block 591: Training on straight_line
#
# Block 592: Training on sine
#
# Block 593: Training on exp
#
# Block 594: Training on polynomial
#
# Block 595: Training on sine
#
# Evaluation at iteration 59500:
#   sine: MSE = 0.2775
#   exp: MSE = 0.0519
#   polynomial: MSE = 0.3383
#   straight_line: MSE = 0.0835
# Average MSE across all families: 0.1878
#
# Block 596: Training on polynomial
#
# Block 597: Training on exp
#
# Block 598: Training on straight_line
#
# Block 599: Training on straight_line
#
# Block 600: Training on sine
#
# Evaluation at iteration 60000:
#   sine: MSE = 0.2741
#   exp: MSE = 0.0717
#   polynomial: MSE = 0.5384
#   straight_line: MSE = 0.0645
# Average MSE across all families: 0.2372
#
# Block 601: Training on straight_line
#
# Block 602: Training on exp
#
# Block 603: Training on straight_line
#
# Block 604: Training on polynomial
#
# Block 605: Training on sine
#
# Evaluation at iteration 60500:
#   sine: MSE = 0.2836
#   exp: MSE = 0.0451
#   polynomial: MSE = 0.3492
#   straight_line: MSE = 0.0609
# Average MSE across all families: 0.1847
#
# Block 606: Training on sine
#
# Block 607: Training on polynomial
#
# Block 608: Training on sine
#
# Block 609: Training on sine
#
# Block 610: Training on polynomial
#
# Evaluation at iteration 61000:
#   sine: MSE = 0.2846
#   exp: MSE = 0.0600
#   polynomial: MSE = 0.3012
#   straight_line: MSE = 0.0977
# Average MSE across all families: 0.1859
#
# Block 611: Training on straight_line
#
# Block 612: Training on straight_line
#
# Block 613: Training on straight_line
#
# Block 614: Training on sine
#
# Block 615: Training on polynomial
#
# Evaluation at iteration 61500:
#   sine: MSE = 0.2946
#   exp: MSE = 0.0534
#   polynomial: MSE = 0.3154
#   straight_line: MSE = 0.0877
# Average MSE across all families: 0.1878
#
# Block 616: Training on polynomial
#
# Block 617: Training on polynomial
#
# Block 618: Training on exp
#
# Block 619: Training on sine
#
# Block 620: Training on sine
#
# Evaluation at iteration 62000:
#   sine: MSE = 0.2541
#   exp: MSE = 0.0809
#   polynomial: MSE = 0.4024
#   straight_line: MSE = 0.0831
# Average MSE across all families: 0.2051
#
# Block 621: Training on sine
#
# Block 622: Training on polynomial
#
# Block 623: Training on polynomial
#
# Block 624: Training on polynomial
#
# Block 625: Training on sine
#
# Evaluation at iteration 62500:
#   sine: MSE = 0.2684
#   exp: MSE = 0.0572
#   polynomial: MSE = 0.3383
#   straight_line: MSE = 0.0798
# Average MSE across all families: 0.1859
#
# Block 626: Training on exp
#
# Block 627: Training on exp
#
# Block 628: Training on sine
#
# Block 629: Training on straight_line
#
# Block 630: Training on polynomial
#
# Evaluation at iteration 63000:
#   sine: MSE = 0.3085
#   exp: MSE = 0.0767
#   polynomial: MSE = 0.2835
#   straight_line: MSE = 0.1150
# Average MSE across all families: 0.1959
#
# Block 631: Training on polynomial
#
# Block 632: Training on exp
#
# Block 633: Training on exp
#
# Block 634: Training on sine
#
# Block 635: Training on straight_line
#
# Evaluation at iteration 63500:
#   sine: MSE = 0.3175
#   exp: MSE = 0.0225
#   polynomial: MSE = 0.4492
#   straight_line: MSE = 0.0210
# Average MSE across all families: 0.2025
#
# Block 636: Training on straight_line
#
# Block 637: Training on polynomial
#
# Block 638: Training on polynomial
#
# Block 639: Training on straight_line
#
# Block 640: Training on polynomial
#
# Evaluation at iteration 64000:
#   sine: MSE = 0.3066
#   exp: MSE = 0.0609
#   polynomial: MSE = 0.2893
#   straight_line: MSE = 0.0970
# Average MSE across all families: 0.1885
#
# Block 641: Training on exp
#
# Block 642: Training on exp
#
# Block 643: Training on sine
#
# Block 644: Training on sine
#
# Block 645: Training on straight_line
#
# Evaluation at iteration 64500:
#   sine: MSE = 0.3022
#   exp: MSE = 0.0325
#   polynomial: MSE = 0.4402
#   straight_line: MSE = 0.0293
# Average MSE across all families: 0.2010
#
# Block 646: Training on straight_line
#
# Block 647: Training on straight_line
#
# Block 648: Training on exp
#
# Block 649: Training on polynomial
#
# Block 650: Training on polynomial
#
# Evaluation at iteration 65000:
#   sine: MSE = 0.3233
#   exp: MSE = 0.0610
#   polynomial: MSE = 0.2762
#   straight_line: MSE = 0.1042
# Average MSE across all families: 0.1912
#
# Block 651: Training on straight_line
#
# Block 652: Training on straight_line
#
# Block 653: Training on exp
#
# Block 654: Training on straight_line
#
# Block 655: Training on straight_line
#
# Evaluation at iteration 65500:
#   sine: MSE = 0.3856
#   exp: MSE = 0.0199
#   polynomial: MSE = 0.5484
#   straight_line: MSE = 0.0187
# Average MSE across all families: 0.2432
#
# Block 656: Training on polynomial
#
# Block 657: Training on straight_line
#
# Block 658: Training on sine
#
# Block 659: Training on straight_line
#
# Block 660: Training on polynomial
#
# Evaluation at iteration 66000:
#   sine: MSE = 0.3246
#   exp: MSE = 0.0478
#   polynomial: MSE = 0.2817
#   straight_line: MSE = 0.0822
# Average MSE across all families: 0.1841
#
# Block 661: Training on exp
#
# Block 662: Training on straight_line
#
# Block 663: Training on sine
#
# Block 664: Training on exp
#
# Block 665: Training on sine
#
# Evaluation at iteration 66500:
#   sine: MSE = 0.2664
#   exp: MSE = 0.0481
#   polynomial: MSE = 0.4854
#   straight_line: MSE = 0.0509
# Average MSE across all families: 0.2127
#
# Block 666: Training on polynomial
#
# Block 667: Training on straight_line
#
# Block 668: Training on straight_line
#
# Block 669: Training on sine
#
# Block 670: Training on sine
#
# Evaluation at iteration 67000:
#   sine: MSE = 0.2505
#   exp: MSE = 0.0795
#   polynomial: MSE = 0.5173
#   straight_line: MSE = 0.0610
# Average MSE across all families: 0.2271
#
# Block 671: Training on sine
#
# Block 672: Training on straight_line
#
# Block 673: Training on sine
#
# Block 674: Training on polynomial
#
# Block 675: Training on sine
#
# Evaluation at iteration 67500:
#   sine: MSE = 0.2436
#   exp: MSE = 0.0642
#   polynomial: MSE = 0.3439
#   straight_line: MSE = 0.0676
# Average MSE across all families: 0.1798
#
# Block 676: Training on sine
#
# Block 677: Training on sine
#
# Block 678: Training on polynomial
#
# Block 679: Training on polynomial
#
# Block 680: Training on exp
#
# Evaluation at iteration 68000:
#   sine: MSE = 0.3422
#   exp: MSE = 0.0229
#   polynomial: MSE = 0.3662
#   straight_line: MSE = 0.0643
# Average MSE across all families: 0.1989
#
# Block 681: Training on exp
#
# Block 682: Training on polynomial
#
# Block 683: Training on exp
#
# Block 684: Training on sine
#
# Block 685: Training on straight_line
#
# Evaluation at iteration 68500:
#   sine: MSE = 0.2974
#   exp: MSE = 0.0328
#   polynomial: MSE = 0.4409
#   straight_line: MSE = 0.0230
# Average MSE across all families: 0.1985
#
# Block 686: Training on straight_line
#
# Block 687: Training on polynomial
#
# Block 688: Training on straight_line
#
# Block 689: Training on exp
#
# Block 690: Training on polynomial
#
# Evaluation at iteration 69000:
#   sine: MSE = 0.3065
#   exp: MSE = 0.0357
#   polynomial: MSE = 0.2871
#   straight_line: MSE = 0.0691
# Average MSE across all families: 0.1746
#
# Block 691: Training on straight_line
#
# Block 692: Training on straight_line
#
# Block 693: Training on exp
#
# Block 694: Training on straight_line
#
# Block 695: Training on exp
#
# Evaluation at iteration 69500:
#   sine: MSE = 0.3914
#   exp: MSE = 0.0128
#   polynomial: MSE = 0.5282
#   straight_line: MSE = 0.0289
# Average MSE across all families: 0.2403
#
# Block 696: Training on polynomial
#
# Block 697: Training on exp
#
# Block 698: Training on exp
#
# Block 699: Training on exp
#
# Block 700: Training on straight_line
#
# Evaluation at iteration 70000:
#   sine: MSE = 0.3707
#   exp: MSE = 0.0320
#   polynomial: MSE = 0.4990
#   straight_line: MSE = 0.0250
# Average MSE across all families: 0.2317
#
# Block 701: Training on polynomial
#
# Block 702: Training on straight_line
#
# Block 703: Training on straight_line
#
# Block 704: Training on straight_line
#
# Block 705: Training on straight_line
#
# Evaluation at iteration 70500:
#   sine: MSE = 0.3863
#   exp: MSE = 0.0203
#   polynomial: MSE = 0.5298
#   straight_line: MSE = 0.0138
# Average MSE across all families: 0.2376
#
# Block 706: Training on exp
#
# Block 707: Training on exp
#
# Block 708: Training on straight_line
#
# Block 709: Training on exp
#
# Block 710: Training on sine
#
# Evaluation at iteration 71000:
#   sine: MSE = 0.2882
#   exp: MSE = 0.0749
#   polynomial: MSE = 0.5309
#   straight_line: MSE = 0.0565
# Average MSE across all families: 0.2376
#
# Block 711: Training on straight_line
#
# Block 712: Training on sine
#
# Block 713: Training on exp
#
# Block 714: Training on sine
#
# Block 715: Training on exp
#
# Evaluation at iteration 71500:
#   sine: MSE = 0.3060
#   exp: MSE = 0.0151
#   polynomial: MSE = 0.5133
#   straight_line: MSE = 0.0567
# Average MSE across all families: 0.2228
#
# Block 716: Training on polynomial
#
# Block 717: Training on sine
#
# Block 718: Training on exp
#
# Block 719: Training on exp
#
# Block 720: Training on polynomial
#
# Evaluation at iteration 72000:
#   sine: MSE = 0.2967
#   exp: MSE = 0.0498
#   polynomial: MSE = 0.2753
#   straight_line: MSE = 0.0961
# Average MSE across all families: 0.1795
#
# Block 721: Training on sine
#
# Block 722: Training on polynomial
#
# Block 723: Training on polynomial
#
# Block 724: Training on straight_line
#
# ...
#
# Block 761: Training on exp
#
# Block 762: Training on polynomial
#
# Block 763: Training on sine
#
# Block 764: Training on exp
#
# Block 765: Training on polynomial
#
# Evaluation at iteration 76500:
#   sine: MSE = 0.2767
#   exp: MSE = 0.0457
#   polynomial: MSE = 0.2595
#   straight_line: MSE = 0.0823
# Average MSE across all families: 0.1661
#
# Block 766: Training on exp
#
# Block 767: Training on exp
#
# Block 768: Training on polynomial
#
# Block 769: Training on polynomial
#
# Block 770: Training on polynomial
#
# Evaluation at iteration 77000:
#   sine: MSE = 0.2853
#   exp: MSE = 0.0607
#   polynomial: MSE = 0.2478
#   straight_line: MSE = 0.1039
# Average MSE across all families: 0.1744
#
# Block 771: Training on straight_line
#
# Block 772: Training on polynomial
#
# Block 773: Training on straight_line
#
# Block 774: Training on polynomial
#
# Block 775: Training on exp
#
# Evaluation at iteration 77500:
#   sine: MSE = 0.3167
#   exp: MSE = 0.0174
#   polynomial: MSE = 0.3122
#   straight_line: MSE = 0.0417
# Average MSE across all families: 0.1720
#
# Block 776: Training on sine
#
# Block 777: Training on polynomial
#
# Block 778: Training on sine
#
# Block 779: Training on sine
#
# Block 780: Training on straight_line
#
# Evaluation at iteration 78000:
#   sine: MSE = 0.2979
#   exp: MSE = 0.0224
#   polynomial: MSE = 0.3773
#   straight_line: MSE = 0.0215
# Average MSE across all families: 0.1798
#
# Block 781: Training on straight_line
#
# Block 782: Training on straight_line
#
# Block 783: Training on sine
#
# Block 784: Training on straight_line
#
# Block 785: Training on straight_line
#
# Evaluation at iteration 78500:
#   sine: MSE = 0.3400
#   exp: MSE = 0.0223
#   polynomial: MSE = 0.4948
#   straight_line: MSE = 0.0159
# Average MSE across all families: 0.2182
#
# Block 786: Training on straight_line
#
# Block 787: Training on straight_line
#
# Block 788: Training on sine
#
# Block 789: Training on sine
#
# Block 790: Training on sine
#
# Evaluation at iteration 79000:
#   sine: MSE = 0.2263
#   exp: MSE = 0.0766
#   polynomial: MSE = 0.5162
#   straight_line: MSE = 0.0616
# Average MSE across all families: 0.2201
#
# Block 791: Training on exp
#
# Block 792: Training on sine
#
# Block 793: Training on exp
#
# Block 794: Training on straight_line
#
# Block 795: Training on exp
#
# Evaluation at iteration 79500:
#   sine: MSE = 0.3354
#   exp: MSE = 0.0137
#   polynomial: MSE = 0.4954
#   straight_line: MSE = 0.0179
# Average MSE across all families: 0.2156
#
# Block 796: Training on straight_line
#
# Block 797: Training on sine
#
# Block 798: Training on straight_line
#
# Block 799: Training on straight_line
#
# Block 800: Training on sine
#
# Evaluation at iteration 80000:
#   sine: MSE = 0.2450
#   exp: MSE = 0.0668
#   polynomial: MSE = 0.5509
#   straight_line: MSE = 0.0594
# Average MSE across all families: 0.2305
#
# Block 801: Training on exp
#
# Block 802: Training on exp
#
# Block 803: Training on straight_line
#
# Block 804: Training on exp
#
# Block 805: Training on exp
#
# Evaluation at iteration 80500:
#   sine: MSE = 0.3566
#   exp: MSE = 0.0126
#   polynomial: MSE = 0.5481
#   straight_line: MSE = 0.0190
# Average MSE across all families: 0.2341
#
# Block 806: Training on polynomial
#
# Block 807: Training on polynomial
#
# Block 808: Training on polynomial
#
# Block 809: Training on straight_line
#
# Block 810: Training on sine
#
# Evaluation at iteration 81000:
#   sine: MSE = 0.2464
#   exp: MSE = 0.0485
#   polynomial: MSE = 0.4457
#   straight_line: MSE = 0.0373
# Average MSE across all families: 0.1945
#
# Block 811: Training on polynomial
#
# Block 812: Training on exp
#
# Block 813: Training on polynomial
#
# Block 814: Training on straight_line
#
# Block 815: Training on straight_line
#
# Evaluation at iteration 81500:
#   sine: MSE = 0.3400
#   exp: MSE = 0.0221
#   polynomial: MSE = 0.4702
#   straight_line: MSE = 0.0198
# Average MSE across all families: 0.2130
#
# Block 816: Training on polynomial
#
# Block 817: Training on polynomial
#
# Block 818: Training on exp
#
# Block 819: Training on sine
#
# Block 820: Training on sine
#
# Evaluation at iteration 82000:
#   sine: MSE = 0.2273
#   exp: MSE = 0.0604
#   polynomial: MSE = 0.3491
#   straight_line: MSE = 0.0514
# Average MSE across all families: 0.1721
#
# Block 821: Training on sine
#
# Block 822: Training on exp
#
# Block 823: Training on straight_line
#
# Block 824: Training on exp
#
# Block 825: Training on exp
#
# Evaluation at iteration 82500:
#   sine: MSE = 0.3434
#   exp: MSE = 0.0123
#   polynomial: MSE = 0.4528
#   straight_line: MSE = 0.0225
# Average MSE across all families: 0.2077
#
# Block 826: Training on polynomial
#
# Block 827: Training on sine
#
# Block 828: Training on straight_line
#
# Block 829: Training on sine
#
# Block 830: Training on sine
#
# Evaluation at iteration 83000:
#   sine: MSE = 0.2176
#   exp: MSE = 0.0664
#   polynomial: MSE = 0.4094
#   straight_line: MSE = 0.0475
# Average MSE across all families: 0.1852
#
# Block 831: Training on straight_line
#
# Block 832: Training on polynomial
#
# Block 833: Training on sine
#
# Block 834: Training on polynomial
#
# Block 835: Training on exp
#
# Evaluation at iteration 83500:
#   sine: MSE = 0.2957
#   exp: MSE = 0.0183
#   polynomial: MSE = 0.3029
#   straight_line: MSE = 0.0627
# Average MSE across all families: 0.1699
#
# Block 836: Training on polynomial
#
# Block 837: Training on exp
#
# Block 838: Training on exp
#
# Block 839: Training on sine
#
# Block 840: Training on polynomial
#
# Evaluation at iteration 84000:
#   sine: MSE = 0.2648
#   exp: MSE = 0.0488
#   polynomial: MSE = 0.2569
#   straight_line: MSE = 0.0818
# Average MSE across all families: 0.1631
#
# Block 841: Training on polynomial
#
# Block 842: Training on exp
#
# Block 843: Training on polynomial
#
# Block 844: Training on straight_line
#
# Block 845: Training on polynomial
#
# Evaluation at iteration 84500:
#   sine: MSE = 0.2865
#   exp: MSE = 0.0574
#   polynomial: MSE = 0.2609
#   straight_line: MSE = 0.0842
# Average MSE across all families: 0.1723
#
# Block 846: Training on exp
#
# Block 847: Training on exp
#
# Block 848: Training on sine
#
# Block 849: Training on polynomial
#
# Block 850: Training on polynomial
#
# Evaluation at iteration 85000:
#   sine: MSE = 0.2809
#   exp: MSE = 0.0498
#   polynomial: MSE = 0.2470
#   straight_line: MSE = 0.0988
# Average MSE across all families: 0.1692
#
# Block 851: Training on sine
#
# Block 852: Training on exp
#
# Block 853: Training on straight_line
#
# Block 854: Training on exp
#
# Block 855: Training on exp
#
# Evaluation at iteration 85500:
#   sine: MSE = 0.3489
#   exp: MSE = 0.0125
#   polynomial: MSE = 0.4291
#   straight_line: MSE = 0.0204
# Average MSE across all families: 0.2027
#
# Block 856: Training on sine
#
# Block 857: Training on exp
#
# Block 858: Training on exp
#
# Block 859: Training on straight_line
#
# Block 860: Training on exp
#
# Evaluation at iteration 86000:
#   sine: MSE = 0.3484
#   exp: MSE = 0.0123
#   polynomial: MSE = 0.4832
#   straight_line: MSE = 0.0308
# Average MSE across all families: 0.2187
#
# Block 861: Training on exp
#
# Block 862: Training on exp
#
# Block 863: Training on exp
#
# Block 864: Training on straight_line
#
# Block 865: Training on polynomial
#
# Evaluation at iteration 86500:
#   sine: MSE = 0.3066
#   exp: MSE = 0.0471
#   polynomial: MSE = 0.2762
#   straight_line: MSE = 0.0710
# Average MSE across all families: 0.1752
#
# Block 866: Training on exp
#
# Block 867: Training on straight_line
#
# Block 868: Training on sine
#
# Block 869: Training on sine
#
# Block 870: Training on polynomial
#
# Evaluation at iteration 87000:
#   sine: MSE = 0.2679
#   exp: MSE = 0.0424
#   polynomial: MSE = 0.2786
#   straight_line: MSE = 0.0626
# Average MSE across all families: 0.1629
#
# Block 871: Training on straight_line
#
# Block 872: Training on straight_line
#
# Block 873: Training on polynomial
#
# Block 874: Training on sine
#
# Block 875: Training on exp
#
# Evaluation at iteration 87500:
#   sine: MSE = 0.2926
#   exp: MSE = 0.0151
#   polynomial: MSE = 0.3527
#   straight_line: MSE = 0.0519
# Average MSE across all families: 0.1781
#
# Block 876: Training on exp
#
# Block 877: Training on straight_line
#
# Block 878: Training on straight_line
#
# Block 879: Training on polynomial
#
# Block 880: Training on sine
#
# Evaluation at iteration 88000:
#   sine: MSE = 0.2423
#   exp: MSE = 0.0563
#   polynomial: MSE = 0.3376
#   straight_line: MSE = 0.0598
# Average MSE across all families: 0.1740
#
# Block 881: Training on polynomial
#
# Block 882: Training on exp
#
# Block 883: Training on straight_line
#
# Block 884: Training on exp
#
# Block 885: Training on polynomial
#
# Evaluation at iteration 88500:
#   sine: MSE = 0.2989
#   exp: MSE = 0.0491
#   polynomial: MSE = 0.2687
#   straight_line: MSE = 0.0647
# Average MSE across all families: 0.1703
#
# Block 886: Training on polynomial
#
# Block 887: Training on straight_line
#
# Block 888: Training on sine
#
# Block 889: Training on exp
#
# Block 890: Training on sine
#
# Evaluation at iteration 89000:
#   sine: MSE = 0.2213
#   exp: MSE = 0.0819
#   polynomial: MSE = 0.4075
#   straight_line: MSE = 0.0519
# Average MSE across all families: 0.1907
#
# Block 891: Training on polynomial
#
# Block 892: Training on exp
#
# Block 893: Training on polynomial
#
# Block 894: Training on straight_line
#
# Block 895: Training on exp
#
# Evaluation at iteration 89500:
#   sine: MSE = 0.3145
#   exp: MSE = 0.0148
#   polynomial: MSE = 0.4745
#   straight_line: MSE = 0.1195
# Average MSE across all families: 0.2308
#
# Block 896: Training on polynomial
#
# Block 897: Training on polynomial
#
# Block 898: Training on exp
#
# Block 899: Training on polynomial
#
# Block 900: Training on sine
#
# Evaluation at iteration 90000:
#   sine: MSE = 0.2405
#   exp: MSE = 0.0437
#   polynomial: MSE = 0.2918
#   straight_line: MSE = 0.0580
# Average MSE across all families: 0.1585
#
# Block 901: Training on polynomial
#
# Block 902: Training on sine
#
# Block 903: Training on exp
#
# Block 904: Training on polynomial
#
# Block 905: Training on sine
#
# Evaluation at iteration 90500:
#   sine: MSE = 0.2210
#   exp: MSE = 0.0637
#   polynomial: MSE = 0.2870
#   straight_line: MSE = 0.0672
# Average MSE across all families: 0.1597
#
# Block 906: Training on straight_line
#
# Block 907: Training on sine
#
# Block 908: Training on sine
#
# Block 909: Training on exp
#
# Block 910: Training on sine
#
# Evaluation at iteration 91000:
#   sine: MSE = 0.2171
#   exp: MSE = 0.0602
#   polynomial: MSE = 0.3837
#   straight_line: MSE = 0.0454
# Average MSE across all families: 0.1766
#
# Block 911: Training on sine
#
# Block 912: Training on exp
#
# Block 913: Training on polynomial
#
# Block 914: Training on sine
#
# Block 915: Training on sine
#
# Evaluation at iteration 91500:
#   sine: MSE = 0.2055
#   exp: MSE = 0.0635
#   polynomial: MSE = 0.3331
#   straight_line: MSE = 0.0699
# Average MSE across all families: 0.1680
#
# Block 916: Training on polynomial
#
# Block 917: Training on straight_line
#
# Block 918: Training on exp
#
# Block 919: Training on exp
#
# Block 920: Training on straight_line
#
# Evaluation at iteration 92000:
#   sine: MSE = 0.3186
#   exp: MSE = 0.0295
#   polynomial: MSE = 0.4580
#   straight_line: MSE = 0.0239
# Average MSE across all families: 0.2075
#
# Block 921: Training on straight_line
#
# Block 922: Training on exp
#
# Block 923: Training on polynomial
#
# Block 924: Training on polynomial
#
# Block 925: Training on exp
#
# Evaluation at iteration 92500:
#   sine: MSE = 0.3061
#   exp: MSE = 0.0146
#   polynomial: MSE = 0.3065
#   straight_line: MSE = 0.0611
# Average MSE across all families: 0.1721
#
# Block 926: Training on polynomial
#
# Block 927: Training on straight_line
#
# Block 928: Training on straight_line
#
# Block 929: Training on sine
#
# Block 930: Training on straight_line
#
# Evaluation at iteration 93000:
#   sine: MSE = 0.2771
#   exp: MSE = 0.0388
#   polynomial: MSE = 0.4124
#   straight_line: MSE = 0.0219
# Average MSE across all families: 0.1876
#
# Block 931: Training on polynomial
#
# Block 932: Training on straight_line
#
# Block 933: Training on sine
#
# Block 934: Training on sine
#
# Block 935: Training on straight_line
#
# Evaluation at iteration 93500:
#   sine: MSE = 0.2749
#   exp: MSE = 0.0273
#   polynomial: MSE = 0.4052
#   straight_line: MSE = 0.0277
# Average MSE across all families: 0.1838
#
# Block 936: Training on straight_line
#
# Block 937: Training on exp
#
# Block 938: Training on sine
#
# Block 939: Training on exp
#
# Block 940: Training on exp
#
# Evaluation at iteration 94000:
#   sine: MSE = 0.3087
#   exp: MSE = 0.0125
#   polynomial: MSE = 0.4540
#   straight_line: MSE = 0.0427
# Average MSE across all families: 0.2045
#
# Block 941: Training on sine
#
# Block 942: Training on polynomial
#
# Block 943: Training on exp
#
# Block 944: Training on exp
#
# Block 945: Training on exp
#
# Evaluation at iteration 94500:
#   sine: MSE = 0.3167
#   exp: MSE = 0.0125
#   polynomial: MSE = 0.3440
#   straight_line: MSE = 0.0347
# Average MSE across all families: 0.1770
#
# Block 946: Training on sine
#
# Block 947: Training on exp
#
# Block 948: Training on exp
#
# Block 949: Training on sine
#
# Block 950: Training on straight_line
#
# Evaluation at iteration 95000:
#   sine: MSE = 0.2910
#   exp: MSE = 0.0336
#   polynomial: MSE = 0.4212
#   straight_line: MSE = 0.0268
# Average MSE across all families: 0.1931
#
# Block 951: Training on sine
#
# Block 952: Training on straight_line
#
# Block 953: Training on exp
#
# Block 954: Training on sine
#
# Block 955: Training on polynomial
#
# Evaluation at iteration 95500:
#   sine: MSE = 0.2536
#   exp: MSE = 0.0474
#   polynomial: MSE = 0.2624
#   straight_line: MSE = 0.0848
# Average MSE across all families: 0.1621
#
# Block 956: Training on polynomial
#
# Block 957: Training on straight_line
#
# Block 958: Training on sine
#
# Block 959: Training on sine
#
# Block 960: Training on straight_line
#
# Evaluation at iteration 96000:
#   sine: MSE = 0.2677
#   exp: MSE = 0.0304
#   polynomial: MSE = 0.4278
#   straight_line: MSE = 0.0286
# Average MSE across all families: 0.1886
#
# Block 961: Training on sine
#
# Block 962: Training on polynomial
#
# Block 963: Training on polynomial
#
# Block 964: Training on exp
#
# Block 965: Training on straight_line
#
# Evaluation at iteration 96500:
#   sine: MSE = 0.3118
#   exp: MSE = 0.0201
#   polynomial: MSE = 0.4111
#   straight_line: MSE = 0.0215
# Average MSE across all families: 0.1911
#
# Block 966: Training on exp
#
# Block 967: Training on polynomial
#
# Block 968: Training on exp
#
# Block 969: Training on straight_line
#
# Block 970: Training on polynomial
#
# Evaluation at iteration 97000:
#   sine: MSE = 0.2885
#   exp: MSE = 0.0335
#   polynomial: MSE = 0.2526
#   straight_line: MSE = 0.0618
# Average MSE across all families: 0.1591
#
# Block 971: Training on polynomial
#
# Block 972: Training on straight_line
#
# Block 973: Training on straight_line
#
# Block 974: Training on sine
#
# Block 975: Training on polynomial
#
# Evaluation at iteration 97500:
#   sine: MSE = 0.2623
#   exp: MSE = 0.0447
#   polynomial: MSE = 0.2524
#   straight_line: MSE = 0.0632
# Average MSE across all families: 0.1557
#
# Block 976: Training on polynomial
#
# Block 977: Training on straight_line
#
# Block 978: Training on sine
#
# Block 979: Training on polynomial
#
# Block 980: Training on sine
#
# Evaluation at iteration 98000:
#   sine: MSE = 0.2220
#   exp: MSE = 0.0446
#   polynomial: MSE = 0.2872
#   straight_line: MSE = 0.0518
# Average MSE across all families: 0.1514
#
# Block 981: Training on straight_line
#
# Block 982: Training on straight_line
#
# Block 983: Training on sine
#
# Block 984: Training on straight_line
#
# Block 985: Training on polynomial
#
# Evaluation at iteration 98500:
#   sine: MSE = 0.2769
#   exp: MSE = 0.0422
#   polynomial: MSE = 0.2594
#   straight_line: MSE = 0.0615
# Average MSE across all families: 0.1600
#
# Block 986: Training on straight_line
#
# Block 987: Training on sine
#
# Block 988: Training on sine
#
# Block 989: Training on polynomial
#
# Block 990: Training on sine
#
# Evaluation at iteration 99000:
#   sine: MSE = 0.2159
#   exp: MSE = 0.0614
#   polynomial: MSE = 0.2871
#   straight_line: MSE = 0.0518
# Average MSE across all families: 0.1540
#
# Block 991: Training on polynomial
#
# Block 992: Training on polynomial
#
# Block 993: Training on exp
#
# Block 994: Training on polynomial
#
# Block 995: Training on straight_line
#
# Evaluation at iteration 99500:
#   sine: MSE = 0.2868
#   exp: MSE = 0.0229
#   polynomial: MSE = 0.3579
#   straight_line: MSE = 0.0246
# Average MSE across all families: 0.1730
#
# Block 996: Training on polynomial
#
# Block 997: Training on exp
#
# Block 998: Training on sine
#
# Block 999: Training on polynomial
#
# Block 1000: Training on exp
#
# Evaluation at iteration 100000:
#   sine: MSE = 0.2803
#   exp: MSE = 0.0204
#   polynomial: MSE = 0.2892
#   straight_line: MSE = 0.0339
# Average MSE across all families: 0.1560
# Final Evaluation and Visualization:
